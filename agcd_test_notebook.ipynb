# %%
from estimator import AGCD

# %%
# Parameters 
dghv_params = AGCD.Parameters(gamma = 19575950, eta = 2698, rho = 71)
AGCD.estimate(dghv_params)
# Out:
# === Step 1: Feasibility ===
#   gamma - rho = 19575879.00
#   eta   - rho = 2627.00
#   Minimum n for attack: n > 7451.8002
#
# === Step 2: Optimal n and delta_0 ===
#   Optimal n (continuous) = 14903.6003
#   Rounded n              = 14904
#   log2(delta_0) bound    = 0.087203
#   delta_0 bound          = 1.06230856
#
# === Step 3: BKZ Blocksize ===
#   Minimum beta = 40
#   delta_0 achieved at beta: 1.01295000
#
# === Step 4: Attack Cost  ===
#   Sieving cost:  log2(T_sieve) = 39.56 bits
#   LLL cost:      log2(T_lll)   = 78.79 bits
#   Reduction regime dominated by LLL
#   Trivial cost:  eta           = 2698 bits
#   GCD cost:      log2(T_gcd)   = 147.62 bits
#   Bottleneck:    log2(T)       = 78.79 bits
#
# === Result ===
#   T      ≈ 2^78.79 clock cycles
#   lambda ≈ 78.79 bits
# Estimated time cost for achieving 78.79 bits of security, with beta = 40: 5.233071707595193e+23 clock cycles
# {'rho_eff': 71,
#  'n': 14904,
#  'delta0': 1.062308563540001,
#  'beta': 40,
# ...

# %%
dghv_params = AGCD.Parameters(gamma = 2200000, eta = 492, rho = 34)
AGCD.estimate(dghv_params)
# Out:
# === Step 1: Feasibility ===
#   gamma - rho = 2199966.00
#   eta   - rho = 458.00
#   Minimum n for attack: n > 4803.4192
#
# === Step 2: Optimal n and delta_0 ===
#   Optimal n (continuous) = 9606.8384
#   Rounded n              = 9607
#   log2(delta_0) bound    = 0.022460
#   delta_0 bound          = 1.01568994
#
# === Step 3: BKZ Blocksize ===
#   Minimum beta = 40
#   delta_0 achieved at beta: 1.01295000
#
# === Step 4: Attack Cost  ===
#   Sieving cost:  log2(T_sieve) = 38.93 bits
#   LLL cost:      log2(T_lll)   = 71.01 bits
#   Reduction regime dominated by LLL
#   Trivial cost:  eta           = 492 bits
#   GCD cost:      log2(T_gcd)   = 86.64 bits
#   Bottleneck:    log2(T)       = 71.01 bits
#
# === Result ===
#   T      ≈ 2^71.01 clock cycles
#   lambda ≈ 71.01 bits
# Estimated time cost for achieving 71.01 bits of security, with beta = 40: 2.371669227088986e+21 clock cycles
# {'rho_eff': 34,
#  'n': 9607,
#  'delta0': 1.0156899444073209,
#  'beta': 40,
# ...

# %%
hilder_params =  AGCD.Parameters(gamma = 87040, eta = 105, rho = 100)
AGCD.estimate(hilder_params)
# Out:
# === Step 1: Feasibility ===
#   gamma - rho = 86940.00
#   eta   - rho = 5.00
#   Minimum n for attack: n > 17388.0000
#
#   WARNING: delta_0 bound is non-positive (0.000072).
#   The scheme appears secure against this OL attack.
#
# === Step 2: Optimal n and delta_0 ===
#   Optimal n (continuous) = 34776.0000
#   Rounded n              = 34776
#   log2(delta_0) bound    = 0.000072
#   delta_0 bound          = 1.00004977
#
# === Step 3: BKZ Blocksize ===
#   Minimum beta = 85587
#   delta_0 achieved at beta: 1.00004977
#
# === Step 4: Attack Cost  ===
#   Sieving cost:  log2(T_sieve) = 17791.79 bits
#   LLL cost:      log2(T_lll)   = 68.38 bits
#   Reduction regime dominated by sieving
#   Trivial cost:  eta           = 105 bits
#   GCD cost:      log2(T_gcd)   = 183.73 bits
#   Bottleneck:    log2(T)       = 105.00 bits
#
# === Result ===
#   T      ≈ 2^105.00 clock cycles
#   lambda ≈ 105.00 bits
#   WARNING: Trivial attack is better than lattice reduction.
# ...
